# %%
from prolog_rag_project.core.prolog_rag import PrologRAG
import logging

# Set up logging to see details if needed
logging.basicConfig(level=logging.INFO)

print("--- Starting Prolog-RAG Demo ---")
print("Initializing system pipeline...")
rag = PrologRAG()
print("\nProlog-RAG is ready for queries!")
